# %%
#Nesta tarefa vamos usar o OpenSSL e Keybase. Eles oferecem serviços de criptografia assimétrica.

#Decifre o texto abaixo em formato base64 usando o OpenSSL para obter os próximos passos. Ele foi cifrado com o algoritmo -aes-256-cbc -salt -pbkdf2 e com a chave simétrica "12345". Siga os passos e submeta a resposta da tarefa.

TEXTO=""""""

# %%
arquivo_cifrado = "cifrado.b64"

with open(arquivo_cifrado, "w") as f:
    f.write(TEXTO)

print("Texto base64 salvo em:", arquivo_cifrado)
# Out:
# Texto base64 salvo em: cifrado.b64

# %% [markdown]
# ```bash
# openssl enc -d -aes-256-cbc -salt -pbkdf2 -base64 -k 12345 -in cifrado.b64 -out saida.txt
# ```

# %%
with open("saida.txt", "r") as f:
    print(f.read())
# Out:
# 1- Se você ainda não possui uma conta no keybase.io, crie uma seguindo as instruções do site.
#
# 2 - Utilize a aplicação web https://keybase.io/encrypt para CIFRAR e ASSINAR uma mensagem para o destinatário gagliotti (perfil disponível em https://keybase.io/gagliotti). Você escolhe conteúdo da mensagem.
#
# 3 - Salve o resultado (a mensagem cifrada e assinada) em um arquivo .txt e submeta-o como resposta desta tarefa.
#
# O conteúdo do arquivo .txt deve ser algo parecido com o seguinte:
#
# -----BEGIN PGP MESSAGE-----
# Version: Keybase OpenPGP v2.1.17
# Comment: https://keybase.io/crypto
#
# wcFMA92Xdcl5WiJ4AQ/+K2i6j+KZtIXsbNDwSLIARbr5yaL+XwkSYzIwzSXXcQNO
# L/ZWmtjO7FDZhM+8qhdZWHdSuZ8Kkvn8uMO6UIzgWwMbBWhF5h0ZnNzL0dtpg0fx
# FI922waoFo+hUU8TT8T2JblUgqoIyM/2EP0KngprRr0dOsSts1JqnYAsPqk8PkqH
# F4xMCGyhvbx7mkJAxaiqxn9g/2qYtutmpVzMjC8Hyqp0Dd+J9JYWtv8etObAuDNv
# dW+nlDlr5FN3vngJcUbTO2oB6e9q+Qh1zsyrOjUz99SrClBjvpMvqY5lkJlZW4hB
# ...

# %% [markdown]
# O texto está protegido por **criptografia simétrica forte** (AES-256). Não dá para "adivinhar" o conteúdo: só
# é possível decifrar quem tiver a **senha**, que o enunciado já forneceu (`12345`).
